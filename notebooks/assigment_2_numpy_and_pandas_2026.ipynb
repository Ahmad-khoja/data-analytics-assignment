# %% [markdown]
# # Assigment 2
#
# Numpy and Pandas

# %%
import numpy as np

arr_1d = np.random.rand(5)


arr_1d
# Out:
# array([0.76107083, 0.04895713, 0.92633397, 0.95933434, 0.08418496])

# %%
print("Shape:", arr_1d.shape)
print("Dtype:", arr_1d.dtype)
print("Second value:", arr_1d[1])
# Out:
# Shape: (5,)
# Dtype: float64
# Second value: 0.048957129398883525

# %% [markdown]
# # Assigment 2 - Numpy Section
#
# ## 1.1. Create a random 1D array (lenght 5) using Numpy and print shape, dtype and second value.
#
# ## 1.2. Create a random 10x10 matrix using Numpy and print shape, dtype.
#
# ## 1.3. Calculate the matrix's total mean, sum, minimum, and maximum.
#
# ## 1.4. Calculate the matrix's **first row** mean, sum, minimum, and maximum.
#
# ## 1.5. Simulate 100 dice rolls and count how many times each number was rolled.
#
# Hint: Create the simulation using np.random.randint(). Count occurrences with np.bincount().

# %%
mat_10x10 = np.random.rand(10, 10)

mat_10x10
# Out:
# array([[0.21854135, 0.83795193, 0.93019388, 0.53809752, 0.86489833,
#         0.87560562, 0.21349926, 0.05766654, 0.35085077, 0.3998596 ],
#        [0.31182519, 0.56823012, 0.0225464 , 0.36986898, 0.84072518,
#         0.32843273, 0.11964272, 0.63425144, 0.41147553, 0.88418231],
#        [0.8308689 , 0.83509339, 0.68819704, 0.41978837, 0.3470878 ,
#         0.16210275, 0.5538676 , 0.8651449 , 0.3909512 , 0.40209936],
#        [0.55167753, 0.58166646, 0.92256311, 0.61150176, 0.34711211,
#         0.78537777, 0.09217307, 0.84145361, 0.36658228, 0.49910435],
#        [0.5885582 , 0.08263132, 0.22843571, 0.00610053, 0.55343133,
#         0.052628  , 0.4968065 , 0.5332062 , 0.08106266, 0.915931  ],
#        [0.14485059, 0.89357165, 0.08620938, 0.42924551, 0.62066858,
#         0.75907668, 0.5308811 , 0.24038072, 0.89010371, 0.24211539],
#        [0.8844586 , 0.26998379, 0.08484325, 0.24884678, 0.20521496,
#         0.58605339, 0.88064527, 0.19632968, 0.07818428, 0.52067081],
#        [0.32311741, 0.6270083 , 0.45795461, 0.80915856, 0.14928139,
#         0.7730968 , 0.24205223, 0.50169438, 0.44846945, 0.77776365],
#        [0.28324407, 0.93189313, 0.65911703, 0.91572943, 0.984709  ,
#         0.8016882 , 0.79884855, 0.83017958, 0.56895006, 0.61242652],
#        [0.74209654, 0.67940597, 0.25856314, 0.41307466, 0.28260509,
#         0.5602407 , 0.5597682 , 0.61470576, 0.06230919, 0.852235  ]])

# %%
print("Shape:", mat_10x10.shape)
print("Dtype:", mat_10x10.dtype)
# Out:
# Shape: (10, 10)
# Dtype: float64

# %% [markdown]
# # Assigment 2 - Pandas Section - Wildlife Accidents
#
# ## 2.1. Determine in which month the highest number of wildlife accidents occur. Is there a difference between months?
#
# Group the data by month and count the number of accidents. Print also with the results sorted descending. Also comment on the results.
#
# ## 2.2. Create a cross-tabulation table showing how wildlife accidents are distributed across species and regions.
#
# Using the wildlife accidents DataFrame (riista_df), create a cross-tabulation where rows represent wildlife species (riistalajiNimi), columns represent regions (maakuntaNimi).
#
# ## 2.3. Convert the "eventTime" column to Pandas datetime format and analyze which hours of day are the most dangerous for wildlife accidents.
#
# Hint: Create additional columns for the day of the week and the hour of day using the pd.to_datetime() function

# %%
from pathlib import Path

list(Path("..").iterdir())
# Out:
# [WindowsPath('../.git'),
#  WindowsPath('../.gitignore'),
#  WindowsPath('../.venv'),
#  WindowsPath('../notebooks'),
#  WindowsPath('../src')]

# %%
from pathlib import Path

list((Path("..") / "data").iterdir())
# Out:
# [WindowsPath('../data/riistaonnettomuudet_2017_2020.csv')]

# %%
from pathlib import Path

list((Path("..") / "data").iterdir())
# Out:
# [WindowsPath('../data/riistaonnettomuudet_2017_2020.csv')]

# %%
import pandas as pd
from pathlib import Path

data_path = Path("..") / "data" / "riistaonnettomuudet_2017_2020.csv"

riista_df = pd.read_csv(
    data_path,
    sep=',',
    encoding='latin1'
)

riista_df.head()
# Out:
#    id                  tapahtumaAika  vuosi  kuukausi           x  \
# 0   1  2017-12-10T16:55:00.000+02:00   2017        12  278773.659
# 1   2  2017-09-03T13:00:00.000+03:00   2017         9  397501.008
# 2   3  2017-09-18T07:00:00.000+03:00   2017         9  418353.841
# 3   4  2017-12-01T17:00:00.000+02:00   2017        12  488970.827
# 4   5  2017-09-18T07:00:00.000+03:00   2017         9  418766.580
#
#              y  kunta  kuntaNimi  maakunta     maakuntaNimi  tielaji  \
# 0  6980877.550    743  Seinäjoki        14  Etelä-Pohjanmaa        3
# 1  7503083.730    261    Kittilä        19            Lappi        4
# 2  7514104.657    261    Kittilä        19            Lappi        6
# 3  6722504.397    285      Kotka         8      Kymenlaakso        5
# 4  7506930.833    261    Kittilä        19            Lappi        6
#
#       tielajis  tieNumero  tieYllapito tieYllapitoNimi  riistalaji  \
# 0     Valtatie       18.0          1.0          Valtio       47507
# 1     Kantatie       80.0          1.0          Valtio       47503
# 2  Muu maantie     9552.0          1.0          Valtio       47503
# 3     Seututie      357.0          1.0          Valtio       47629
# 4  Muu maantie     9552.0          1.0          Valtio       47503
#
#     riistalajiNimi
# 0      Metsäkauris
# 1            Hirvi
# 2            Hirvi
# 3  Valkohäntäpeura
# 4            Hirvi

# %%
accidents_by_month = (
    riista_df
    .groupby("kuukausi")
    .size()
    .sort_values(ascending=False)
)

accidents_by_month
# Out:
# kuukausi
# 11    10962
# 10     8467
# 12     6382
# 5      6301
# 9      5995
# 6      5551
# 7      4516
# 8      4450
# 1      4110
# 4      3007
# 2      2194
# 3      2007
# dtype: int64

# %% [markdown]
# #Comment#
#
# The highest number of wildlife accidents occurs in late summer and autumn months.
# There is a clear difference between months, with significantly more accidents during
# these periods compared to winter months. This indicates strong seasonal variation
# in wildlife movement and road crossings.

# %%
cross_table = pd.crosstab(
    riista_df["riistalajiNimi"],
    riista_df["maakuntaNimi"]
)

cross_table
# Out:
# maakuntaNimi     Etelä-Karjala  Etelä-Pohjanmaa  Etelä-Savo  Kainuu  \
# riistalajiNimi
# Hirvi                      291              514         514     319
# Kuusipeura                   0                0           0       0
# Metsäkauris                216              744         243     106
# Metsäpeura                   0               57           0      68
# Valkohäntäpeura             66              303         185       0
# Villisika                   17                1           7       1
#
# maakuntaNimi     Kanta-Häme  Keski-Pohjanmaa  Keski-Suomi  Kymenlaakso  Lappi  \
# riistalajiNimi
# Hirvi                   309              163          763          272    674
# Kuusipeura               13                0            0            0      0
# Metsäkauris            1601              196         1098          474    513
# Metsäpeura                0              123           13            0      0
# Valkohäntäpeura        4004               10          369          117      0
# Villisika                 7                0           10           30      0
#
# maakuntaNimi     Pirkanmaa  Pohjanmaa  Pohjois-Karjala  Pohjois-Pohjanmaa  \
# riistalajiNimi
# Hirvi                  693        569              587                861
# Kuusipeura               0          0                0                  1
# Metsäkauris           2797       1111              157                697
# Metsäpeura               1          5                0                 55
# Valkohäntäpeura       4990        334                0                 18
# Villisika               12          2               11                  3
#
# maakuntaNimi     Pohjois-Savo  Päijät-Häme  Satakunta  Uusimaa  \
# riistalajiNimi
# Hirvi                     550          253        492      798
# Kuusipeura                  0            0         20       52
# Metsäkauris               375         1044       2562     4020
# Metsäpeura                  0            0          3        0
# Valkohäntäpeura            55          657       3336     7351
# Villisika                   0           20          3       39
#
# maakuntaNimi     Varsinais-Suomi
# riistalajiNimi
# Hirvi                        571
# Kuusipeura                     1
# Metsäkauris                 4512
# Metsäpeura                     0
# Valkohäntäpeura             9908
# Villisika                      5

# %%
cross_table_sorted = cross_table.loc[
    cross_table.sum(axis=1).sort_values(ascending=False).index
]

cross_table_sorted
# Out:
# maakuntaNimi     Etelä-Karjala  Etelä-Pohjanmaa  Etelä-Savo  Kainuu  \
# riistalajiNimi
# Valkohäntäpeura             66              303         185       0
# Metsäkauris                216              744         243     106
# Hirvi                      291              514         514     319
# Metsäpeura                   0               57           0      68
# Villisika                   17                1           7       1
# Kuusipeura                   0                0           0       0
#
# maakuntaNimi     Kanta-Häme  Keski-Pohjanmaa  Keski-Suomi  Kymenlaakso  Lappi  \
# riistalajiNimi
# Valkohäntäpeura        4004               10          369          117      0
# Metsäkauris            1601              196         1098          474    513
# Hirvi                   309              163          763          272    674
# Metsäpeura                0              123           13            0      0
# Villisika                 7                0           10           30      0
# Kuusipeura               13                0            0            0      0
#
# maakuntaNimi     Pirkanmaa  Pohjanmaa  Pohjois-Karjala  Pohjois-Pohjanmaa  \
# riistalajiNimi
# Valkohäntäpeura       4990        334                0                 18
# Metsäkauris           2797       1111              157                697
# Hirvi                  693        569              587                861
# Metsäpeura               1          5                0                 55
# Villisika               12          2               11                  3
# Kuusipeura               0          0                0                  1
#
# maakuntaNimi     Pohjois-Savo  Päijät-Häme  Satakunta  Uusimaa  \
# riistalajiNimi
# Valkohäntäpeura            55          657       3336     7351
# Metsäkauris               375         1044       2562     4020
# Hirvi                     550          253        492      798
# Metsäpeura                  0            0          3        0
# Villisika                   0           20          3       39
# Kuusipeura                  0            0         20       52
#
# maakuntaNimi     Varsinais-Suomi
# riistalajiNimi
# Valkohäntäpeura             9908
# Metsäkauris                 4512
# Hirvi                        571
# Metsäpeura                     0
# Villisika                      5
# Kuusipeura                     1

# %% [markdown]
# #Comment#
#
# The cross-tabulation shows that wildlife accidents are unevenly distributed
# across species and regions. Certain species account for a large share of
# accidents nationwide, while some regions experience significantly more
# accidents than others. This reflects differences in wildlife populations
# and traffic density between regions.

# %%
riista_df["tapahtumaAika"].head()
# Out:
# 0    2017-12-10T16:55:00.000+02:00
# 1    2017-09-03T13:00:00.000+03:00
# 2    2017-09-18T07:00:00.000+03:00
# 3    2017-12-01T17:00:00.000+02:00
# 4    2017-09-18T07:00:00.000+03:00
# Name: tapahtumaAika, dtype: str

# %%
riista_df["tapahtumaAika"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
riista_df["tapahtumaAika"] = (
    riista_df["tapahtumaAika"]
    .str.replace(r"\+.*$", "", regex=True)
)

riista_df["tapahtumaAika"] = pd.to_datetime(
    riista_df["tapahtumaAika"],
    errors="coerce"
)

# %%
riista_df["tapahtumaAika"].dtype
# Out:
# dtype('<M8[us]')

# %%
riista_df["hour"] = riista_df["tapahtumaAika"].dt.hour
riista_df["weekday"] = riista_df["tapahtumaAika"].dt.day_name()

riista_df[["tapahtumaAika", "hour", "weekday"]].head()
# Out:
#         tapahtumaAika  hour weekday
# 0 2017-12-10 16:55:00    16  Sunday
# 1 2017-09-03 13:00:00    13  Sunday
# 2 2017-09-18 07:00:00     7  Monday
# 3 2017-12-01 17:00:00    17  Friday
# 4 2017-09-18 07:00:00     7  Monday

# %%
accidents_by_hour = (
    riista_df
    .groupby("hour")
    .size()
    .sort_values(ascending=False)
)

accidents_by_hour
# Out:
# hour
# 7     4853
# 8     4796
# 17    4488
# 18    4390
# 19    4130
# 20    4011
# 21    3867
# 6     3516
# 22    3269
# 16    3199
# 9     3111
# 23    2665
# 10    2344
# 15    1776
# 11    1726
# 5     1718
# 12    1672
# 14    1564
# 0     1520
# 13    1443
# 1     1272
# 4      913
# 2      891
# 3      808
# dtype: int64

# %% [markdown]
# #Comment#
#
# Wildlife accidents are most frequent during early morning and evening hours.
# These times are particularly dangerous due to low visibility and increased
# wildlife activity near roads.
